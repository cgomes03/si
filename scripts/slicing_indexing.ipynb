# %%
import numpy as np
from si.io.csvfile import read_csv
from si.data.dataset import Dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 from si.io.csvfile import read_csv
#       3 from si.data.dataset import Dataset
#
# ModuleNotFoundError: No module named 'si.io.csvfile'

# %%
dataset = read_csv("si/datasets/iris/iris.csv", features=True, label=True)
